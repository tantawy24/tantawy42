# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
import numpy as np
import math
import time
cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=1)
offset = 20
imgSize = 300
folder = r"C:\Users\Acer\OneDrive\Desktop\حسنا"
counter = 0
while True:
    success, img = cap.read()
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']
        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
        imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]
        imgCropShape = imgCrop.shape
        aspectRatio = h / w
        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            imgResizeShape = imgResize.shape
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            imgResizeShape = imgResize.shape
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize
        cv2.imshow("ImageCrop", imgCrop)
        cv2.imshow("ImageWhite", imgWhite)
    cv2.imshow("Image", img)
    key = cv2.waitKey(1)
    if key == ord("s"):
        counter += 1
        cv2.imwrite(f'{folder}/Image_{time.time()}.jpg',imgWhite)
        print(counter)

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
from cvzone.ClassificationModule import Classifier
import numpy as np
import math
cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=2)
classifier = Classifier(r"D:\Data of\22\keras_model.h5", r"D:\Data of\22\labels.txt")
offset = 20
imgSize = 300
counter = 0
labels = ['I love you','OK']
while True:
    success, img = cap.read()
    imgOutput = img.copy()
    hands, img = detector.findHands(img)
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']
        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
        imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]
        imgCropShape = imgCrop.shape
        aspectRatio = h / w
        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            imgResizeShape = imgResize.shape
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
            prediction, index = classifier.getPrediction(imgWhite, draw=False)
            print(prediction, index)
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            imgResizeShape = imgResize.shape
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize
            prediction, index = classifier.getPrediction(imgWhite, draw=False)
        cv2.rectangle(imgOutput, (x - offset, y - offset-50),
                      (x - offset+90, y - offset-50+50), (255, 0, 255), cv2.FILLED)
        cv2.putText(imgOutput, labels[index], (x, y -26), cv2.FONT_HERSHEY_COMPLEX, 1.7, (255, 255, 255), 2)
        cv2.rectangle(imgOutput, (x-offset, y-offset),
                      (x + w+offset, y + h+offset), (255, 0, 255), 4)
        cv2.imshow("ImageCrop", imgCrop)
        cv2.imshow("ImageWhite", imgWhite)
    cv2.imshow("Image", imgOutput)
    cv2.waitKey(1)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 1s/step
# [0.9700684, 0.029931689] 0
# 1/1 [==============================] - 0s 44ms/step
# [0.99944466, 0.0005553669] 0
# 1/1 [==============================] - 0s 49ms/step
# [0.99979264, 0.00020736776] 0
# ...
# 1/1 [==============================] - 0s 40ms/step
# [0.9995652, 0.00043482587] 0
# ...
# 1/1 [==============================] - 0s 45ms/step
# [0.9637272, 0.036272824] 0
# 1/1 [==============================] - 0s 40ms/step
# [0.28234807, 0.71765196] 1
# 1/1 [==============================] - 0s 42ms/step
# [0.99503124, 0.0049687764] 0
# 1/1 [==============================] - 0s 41ms/step
# [0.9985513, 0.0014486216] 0
# ...
# 1/1 [==============================] - 0s 38ms/step
# [0.99978, 0.00022001503] 0
# 1/1 [==============================] - 0s 36ms/step
# [0.89788735, 0.10211266] 0
# ...

# %%
# !pip install PyArabic
# Out:
# ...
#   Obtaining dependency information for PyArabic from https://files.pythonhosted.org/packages/d7/64/0ea5be39e6a6515804cae8c280226d771f42750a08182f9d2e5f3b822694/PyArabic-0.6.15-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/126.4 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/126.4 kB ? eta -:--:--
#    --------- ----------------------------- 30.7/126.4 kB 435.7 kB/s eta 0:00:01
#    ------------------ -------------------- 61.4/126.4 kB 544.7 kB/s eta 0:00:01
#    --------------------------------- ---- 112.6/126.4 kB 652.2 kB/s eta 0:00:01
#    ------------------------------------ - 122.9/126.4 kB 717.5 kB/s eta 0:00:01
#    -------------------------------------- 126.4/126.4 kB 494.2 kB/s eta 0:00:00
# ...

# %%
# !pip install arabic-reshaper
# Out:
# ...
#   Obtaining dependency information for arabic-reshaper from https://files.pythonhosted.org/packages/44/fb/e20b45d81d74d810b01bff408baf8af04abf1d55a1a289c8395ad0919a7c/arabic_reshaper-3.0.0-py3-none-any.whl.metadata
# ...

# %%
# !pip install front
# Out:
# ...
#      ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#      ---------------------------------------- 0.0/56.1 kB ? eta -:--:--
#      ----------------------------- ---------- 41.0/56.1 kB ? eta -:--:--
#      -------------------------------------- 56.1/56.1 kB 588.4 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Obtaining dependency information for dol from https://files.pythonhosted.org/packages/01/f9/8afbcaad53a633ed6a59ceb9da7943179922d8712659774ce3e6327b93c3/dol-0.2.45-py3-none-any.whl.metadata
# ...
#   Obtaining dependency information for i2 from https://files.pythonhosted.org/packages/57/62/f155d6ef0c7236b62c4ec8e579db0e8e3853929d56c06b8a1a30fa116882/i2-0.1.17-py3-none-any.whl.metadata
# ...

# %%
# !pip install image

# %%
import cv2
from cvzone.HandTrackingModule import HandDetector
from cvzone.ClassificationModule import Classifier
import numpy as np
import math
import arabic_reshaper
from PIL import ImageFont, ImageDraw

cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=2)
classifier = Classifier(r"D:\Data of\22\keras_model.h5", r"D:\Data of\22\labels.txt")
offset = 20
imgSize = 300
counter = 0
labels = ['أحبك', 'موافق']

while True:
    success, img = cap.read()
    imgOutput = img.copy()
    hands, img = detector.findHands(img)
    
    if hands:
        hand = hands[0]
        x, y, w, h = hand['bbox']
        imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
        imgCrop = img[y - offset:y + h + offset, x - offset:x + w + offset]
        imgCropShape = imgCrop.shape
        aspectRatio = h / w
        
        if aspectRatio > 1:
            k = imgSize / h
            wCal = math.ceil(k * w)
            imgResize = cv2.resize(imgCrop, (wCal, imgSize))
            imgResizeShape = imgResize.shape
            wGap = math.ceil((imgSize - wCal) / 2)
            imgWhite[:, wGap:wCal + wGap] = imgResize
            prediction, index = classifier.getPrediction(imgWhite, draw=False)
        else:
            k = imgSize / w
            hCal = math.ceil(k * h)
            imgResize = cv2.resize(imgCrop, (imgSize, hCal))
            imgResizeShape = imgResize.shape
            hGap = math.ceil((imgSize - hCal) / 2)
            imgWhite[hGap:hCal + hGap, :] = imgResize
            prediction, index = classifier.getPrediction(imgWhite, draw=False)
        
        reshaped_label = arabic_reshaper.reshape(labels[index])
        # Render Arabic text
        fontpath = r"D:\Khediawy.ttf"  # You can replace "arial.ttf" with any font that supports Arabic
        font = ImageFont.truetype(fontpath, 36)
        img_pil = Image.fromarray(imgOutput)
        draw = ImageDraw.Draw(img_pil)
        draw.text((x, y - 26), reshaped_label, font=font, fill=(255, 255, 255))
        imgOutput = np.array(img_pil)
        
        cv2.rectangle(imgOutput, (x - offset, y - offset - 50),
                      (x - offset + 90, y - offset - 50 + 50), (255, 0, 255), cv2.FILLED)
        cv2.rectangle(imgOutput, (x - offset, y - offset),
                      (x + w + offset, y + h + offset), (255, 0, 255), 4)
        cv2.imshow("ImageCrop", imgCrop)
        cv2.imshow("ImageWhite", imgWhite)
    
    cv2.imshow("Image", imgOutput)
    cv2.waitKey(1)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.
# 1/1 [==============================] - 1s 1s/step
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 51
#      49 fontpath = r"D:\Khediawy.ttf"  # You can replace "arial.ttf" with any font that supports Arabic
#      50 font = ImageFont.truetype(fontpath, 36)
# ---> 51 img_pil = Image.fromarray(imgOutput)
#      52 draw = ImageDraw.Draw(img_pil)
#      53 draw.text((x, y - 26), reshaped_label, font=font, fill=(255, 255, 255))
#
# NameError: name 'Image' is not defined
